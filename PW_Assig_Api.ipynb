# %% [markdown]
# Q1. What is an API? Give an example, where an API is used in real life.
#
# API (Application Programming Interface):
# - An API is a set of rules and protocols that allows different software applications to communicate with each other. It defines the methods and data formats that applications can use to request and exchange information.
#
# Real-life example:
# - Weather API: Many weather forecasting applications and websites use a weather API to get real-time weather data. For instance, a weather app on your smartphone might use an API provided by a weather service like OpenWeatherMap or Weather.com to display current weather conditions, forecasts, and alerts.
#
# Q2. Give advantages and disadvantages of using API.
#
# Advantages:
# 1. Integration: APIs enable different systems to work together seamlessly, allowing for integration of functionalities from different applications.
# 2. Automation: APIs can automate tasks and workflows, improving efficiency and reducing manual intervention.
# 3. Scalability: APIs can handle a large number of requests and can scale as the application grows.
# 4. Reusability: APIs can be reused across different applications and services, promoting code reuse and consistency.
# 5. Flexibility: APIs allow developers to access certain functionalities without knowing the underlying code or infrastructure.
#
# Disadvantages:
# 1. Complexity: Designing and maintaining an API can be complex and requires careful planning and documentation.
# 2. Security: APIs can be a target for attacks if not properly secured, potentially exposing sensitive data.
# 3. Dependency: Applications that rely heavily on third-party APIs can be affected by changes or downtimes in those APIs.
# 4. Versioning: Managing different versions of an API can be challenging, especially when clients depend on specific versions.
# 5. Performance: APIs can introduce latency and affect the performance of an application if not optimized properly.
#
# Q3. What is a Web API? Differentiate between API and Web API.
#
# Web API:
# - A Web API is a type of API that is accessed over the web using HTTP/HTTPS protocols. It allows communication and data exchange between web servers and clients (such as web browsers or mobile applications).
#
# Difference between API and Web API:
# - API: A general term for any interface that allows software applications to communicate. APIs can be local (within the same system) or remote (over a network).
# - Web API: A specific type of API designed to be accessed over the web using HTTP/HTTPS. It typically involves web-based protocols and data formats like JSON or XML.
#
# Q4. Explain REST and SOAP Architecture. Mention shortcomings of SOAP.
#
# REST (Representational State Transfer):
# - REST is an architectural style for designing networked applications. It relies on a stateless, client-server communication model and uses standard HTTP methods (GET, POST, PUT, DELETE) for CRUD operations. Data is typically exchanged in JSON or XML format.
# - Key principles: Stateless, client-server, cacheable, layered system, uniform interface.
#
# SOAP (Simple Object Access Protocol):
# - SOAP is a protocol for exchanging structured information in web services. It relies on XML-based messaging and can operate over various lower-level protocols (HTTP, SMTP, etc.).
# - Key principles: Extensibility, neutrality, and independence.
#
# Shortcomings of SOAP:
# 1. Complexity: SOAP is more complex to implement and requires a strict XML format.
# 2. Overhead: SOAP messages are larger due to the extensive use of XML, leading to higher latency and bandwidth consumption.
# 3. Tight Coupling: SOAP services are more tightly coupled, making changes and updates more challenging.
# 4. Less Flexibility: SOAP is less flexible compared to REST in terms of data formats and communication protocols.

# %% [markdown]
# Q5. Differentiate between REST and SOAP.

# %%
import pandas as pd

# Data for the comparison between REST and SOAP
data = {
    "Aspect": [
        "Architecture Style",
        "Data Format",
        "Communication",
        "Operations",
        "Stateless",
        "Complexity",
        "Performance",
        "Error Handling",
        "Flexibility",
        "Security"
    ],
    "REST": [
        "Architectural style",
        "Typically JSON, also XML, HTML, plain text",
        "HTTP/HTTPS",
        "Uses standard HTTP methods (GET, POST, PUT, DELETE)",
        "Yes",
        "Simpler to implement",
        "Generally faster due to lightweight messaging (JSON)",
        "HTTP status codes",
        "More flexible with data formats and communication",
        "Relies on HTTP-based security mechanisms"
    ],
    "SOAP": [
        "Protocol",
        "XML",
        "Can use various protocols like HTTP, SMTP, TCP, etc.",
        "Uses specific SOAP actions and WSDL for operations",
        "Not necessarily",
        "More complex with strict standards",
        "Slower due to heavier XML messaging",
        "Detailed error messages with SOAP fault elements",
        "Less flexible, tightly coupled with XML",
        "Built-in security features like WS-Security"
    ]
}

# Creating DataFrame
df = pd.DataFrame(data)

df
# Out:
#                Aspect                                               REST  \
# 0  Architecture Style                                Architectural style
# 1         Data Format         Typically JSON, also XML, HTML, plain text
# 2       Communication                                         HTTP/HTTPS
# 3          Operations  Uses standard HTTP methods (GET, POST, PUT, DE...
# 4           Stateless                                                Yes
# 5          Complexity                               Simpler to implement
# 6         Performance  Generally faster due to lightweight messaging ...
# 7      Error Handling                                  HTTP status codes
# 8         Flexibility  More flexible with data formats and communication
# 9            Security           Relies on HTTP-based security mechanisms
#
#                                                 SOAP
# 0                                           Protocol
# 1                                                XML
# ...
