# %% [markdown]
# Assignment
#
# Data Science Masters
#
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
# - Ans: Matplotlib is a comprehensive data visualization library in Python. It is widely used for creating static, animated, and interactive plots in Python. Matplotlib is built on NumPy arrays and designed to work seamlessly with other libraries like Pandas.
#
# - Matplotlib is used for creating high-quality visualizations in Python. It provides a flexible and customizable platform for creating various types of plots and charts, making it essential for data exploration, analysis, and presentation. It is extensively used in scientific research, data analysis, and machine learning for visualizing data patterns and trends.
#
# - Five plots that can be plotted using the Pyplot module of Matplotlib:
# 1. Line Plot: plt.plot(x, y)
# 2. Scatter Plot: plt.scatter(x, y)
# 3. Histogram: plt.hist(data, bins=5)
# 4. Bar Chart: plt.bar(categories, values)
# 5. Pie Chart: plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
# import numpy as np
# np.random.seed(3)
# x = 3 + np.random.normal(0, 2, 50)
# y = 3 + np.random.normal(0, 2, len(x))
# Note: Also add title, xlabel, and ylabel to the plot.
#
# - Ans :
# A scatter plot is a type of data visualization that displays individual data points on a two-dimensional graph. Each point on the plot represents the values of two variables, allowing for the observation of patterns or relationships between them. Scatter plots are useful for identifying trends, correlations, or clusters in the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data for x and y
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# Create a scatter plot
plt.scatter(x, y)

# Add title and labels
plt.title('Scatter Plot of Generated Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
# import numpy as np
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])
#
# - Ans: The subplot() function in Matplotlib is used to create multiple plots within a single figure. It allows you to arrange plots in a grid, specifying the number of rows and columns in the grid and the position of each subplot.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for line plots
x = np.array([0, 1, 2, 3, 4, 5])

# Data for line 1
y1 = np.array([0, 100, 200, 300, 400, 500])

# Data for line 2
y2 = np.array([50, 20, 40, 20, 60, 70])

# Data for line 3
y3 = np.array([10, 20, 30, 40, 50, 60])

# Data for line 4
y4 = np.array([200, 350, 250, 550, 450, 150])

# Create subplots
plt.subplot(2, 2, 1)
plt.plot(x, y1)
plt.title('Line Plot 1')

plt.subplot(2, 2, 2)
plt.plot(x, y2)
plt.title('Line Plot 2')

plt.subplot(2, 2, 3)
plt.plot(x, y3)
plt.title('Line Plot 3')

plt.subplot(2, 2, 4)
plt.plot(x, y4)
plt.title('Line Plot 4')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
# profit = np.array([3000, 8000, 1000, 10000])
#
# - Ans :
# Bar Plot:
# A bar plot is a type of data visualization that represents categorical data with rectangular bars. The lengths of the bars are proportional to the values they represent. Bar plots are useful for comparing the values of different categories or groups.
#
# - Comparison: Bar plots make it easy to compare the magnitudes of different categories.
# - Categorical Data: Suitable for visualizing and comparing categorical data.
# - Clarity: Provides a clear representation of data distribution.

# %%
import numpy as np
import matplotlib.pyplot as plt

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# Create a bar plot
plt.bar(company, profit, color='blue')
plt.title('Bar Plot - Company Profits')
plt.xlabel('Company')
plt.ylabel('Profit (in millions)')
plt.show()

# Create a horizontal bar plot
plt.barh(company, profit, color='green')
plt.title('Horizontal Bar Plot - Company Profits')
plt.xlabel('Profit (in millions)')
plt.ylabel('Company')
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)
#
# - ans:
# Box Plot:
# A box plot, also known as a box-and-whisker plot, is a statistical visualization that provides a summary of the distribution of a dataset. It displays key statistical measures such as the median, quartiles, and potential outliers.
#
# Why is it used:
# Summary of Distribution:
# Box plots offer a concise summary of the central tendency and spread of a dataset, emphasizing the median, quartiles, and potential outliers.
# Identification of Outliers:
#
# Outliers, or data points that deviate significantly from the overall pattern, can be easily identified in a box plot.
# Comparison of Distributions:
#
# Box plots are useful for comparing the distributions of multiple datasets side by side.
# Skewness and Symmetry:
#
# The box plot visually indicates the skewness or symmetry of the data distribution.
# Compact Visualization:
#
# Provides a compact and space-efficient way to represent the main characteristics of a dataset.
# Robustness to Extreme Values:
#
# Box plots are robust to extreme values and are less affected by outliers compared to some other types of plots.
